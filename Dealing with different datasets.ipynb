# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd

# %% [markdown]
# # IMDB in CSV format

# %%
df=pd.read_csv("IMDB.csv")

# %%
df
# Out:
#        X                              Title  Rating  TotalVotes     Genre1  \
# 0      1            12 Years a Slave (2013)     8.1      496092  Biography
# 1      2                   127 Hours (2010)     7.6      297075  Adventure
# 2      3                       50/50 (2011)     7.7      283935     Comedy
# 3      4                  About Time (2013)     7.8      225412     Comedy
# 4      5                       Amour (2012)     7.9       76121      Drama
# ..   ...                                ...     ...         ...        ...
# 112  114                    Whiplash (2014)     8.5      492285      Drama
# 113  115              Wreck-It Ralph (2012)     7.7      295125  Animation
# 114  116  X-Men: Days of Future Past (2014)     8.0      560736     Action
# 115  117          X-Men: First Class (2011)     7.8      556713     Action
# 116  118                    Zootopia (2016)     8.1      309474  Animation
#
# ...

# %%
df.head(20)
# Out:
#      X                                              Title  Rating  TotalVotes  \
# 0    1                            12 Years a Slave (2013)     8.1      496092
# 1    2                                   127 Hours (2010)     7.6      297075
# 2    3                                       50/50 (2011)     7.7      283935
# 3    4                                  About Time (2013)     7.8      225412
# 4    5                                       Amour (2012)     7.9       76121
# 5    6                                        Argo (2012)     7.7      486840
# 6    7                                     Arrival (2016)     8.0      370842
# 7    9                             Before Midnight (2013)     7.9      106553
# 8   10                                  Big Hero 6 (2014)     7.8      315485
# 9   11  Birdman or (The Unexpected Virtue of Ignorance...     7.8      448725
# 10  12                                  Black Swan (2010)     8.0      587893
# ...

# %%
df.tail()
# Out:
#        X                              Title  Rating  TotalVotes     Genre1  \
# 112  114                    Whiplash (2014)     8.5      492285      Drama
# 113  115              Wreck-It Ralph (2012)     7.7      295125  Animation
# 114  116  X-Men: Days of Future Past (2014)     8.0      560736     Action
# 115  117          X-Men: First Class (2011)     7.8      556713     Action
# 116  118                    Zootopia (2016)     8.1      309474  Animation
#
#         Genre2  Genre3  MetaCritic       Budget  Runtime  ...  Votes45A  \
# 112      Music     NaN        88.0    3300000.0  107 min  ...       8.1
# 113  Adventure  Comedy        72.0  165000000.0      NaN  ...       7.4
# 114  Adventure  Sci-Fi        74.0  200000000.0  132 min  ...       7.7
# 115  Adventure  Sci-Fi        65.0  160000000.0  132 min  ...       7.6
# 116  Adventure  Comedy        78.0  150000000.0  108 min  ...       7.8
#
#      Votes45AM  Votes45AF  VotesIMDB  Votes1000  VotesUS  VotesnUS  \
# ...

# %%
df = pd.read_csv('IMDB.csv',  usecols=['Title', 'Rating', 'Worldwide'])

# %%
df.head(100)
# Out:
#                         Title  Rating      Worldwide
# 0     12 Years a Slave (2013)     8.1  $187,733,202
# 1            127 Hours (2010)     7.6   $60,738,797
# 2                50/50 (2011)     7.7   $39,187,783
# 3           About Time (2013)     7.8   $87,100,449
# 4                Amour (2012)     7.9   $19,839,492
# ..                        ...     ...            ...
# 95  The Imitation Game (2014)     8.1  $233,555,708
# 96   The King's Speech (2010)     8.0  $414,211,549
# 97      The Lego Movie (2014)     7.8  $469,160,692
# 98   The Little Prince (2015)     7.8   $97,571,250
# 99         The Martian (2015)     8.0  $630,161,890
#
# [100 rows x 3 columns]

# %%
df = pd.read_csv('IMDB.csv',  na_values=[''])

# %%
df
# Out:
#        X                              Title  Rating  TotalVotes     Genre1  \
# 0      1            12 Years a Slave (2013)     8.1      496092  Biography
# 1      2                   127 Hours (2010)     7.6      297075  Adventure
# 2      3                       50/50 (2011)     7.7      283935     Comedy
# 3      4                  About Time (2013)     7.8      225412     Comedy
# 4      5                       Amour (2012)     7.9       76121      Drama
# ..   ...                                ...     ...         ...        ...
# 112  114                    Whiplash (2014)     8.5      492285      Drama
# 113  115              Wreck-It Ralph (2012)     7.7      295125  Animation
# 114  116  X-Men: Days of Future Past (2014)     8.0      560736     Action
# 115  117          X-Men: First Class (2011)     7.8      556713     Action
# 116  118                    Zootopia (2016)     8.1      309474  Animation
#
# ...

# %%
df.shape
# Out:
# (117, 58)

# %% [markdown]
# # IMDB Excel

# %%
df_excel=pd.read_excel("IMDB.xlsx")

# %%
df_excel
# Out:
#        X                              Title  Rating  TotalVotes     Genre1  \
# 0      1            12 Years a Slave (2013)     8.1      496092  Biography
# 1      2                   127 Hours (2010)     7.6      297075  Adventure
# 2      3                       50/50 (2011)     7.7      283935     Comedy
# 3      4                  About Time (2013)     7.8      225412     Comedy
# 4      5                       Amour (2012)     7.9       76121      Drama
# ..   ...                                ...     ...         ...        ...
# 112  114                    Whiplash (2014)     8.5      492285      Drama
# 113  115              Wreck-It Ralph (2012)     7.7      295125  Animation
# 114  116  X-Men: Days of Future Past (2014)     8.0      560736     Action
# 115  117          X-Men: First Class (2011)     7.8      556713     Action
# 116  118                    Zootopia (2016)     8.1      309474  Animation
#
# ...

# %%
df_excel = pd.read_excel('IMDB.xlsx', sheet_name=0)

# %%
df_excel
# Out:
#        X                              Title  Rating  TotalVotes     Genre1  \
# 0      1            12 Years a Slave (2013)     8.1      496092  Biography
# 1      2                   127 Hours (2010)     7.6      297075  Adventure
# 2      3                       50/50 (2011)     7.7      283935     Comedy
# 3      4                  About Time (2013)     7.8      225412     Comedy
# 4      5                       Amour (2012)     7.9       76121      Drama
# ..   ...                                ...     ...         ...        ...
# 112  114                    Whiplash (2014)     8.5      492285      Drama
# 113  115              Wreck-It Ralph (2012)     7.7      295125  Animation
# 114  116  X-Men: Days of Future Past (2014)     8.0      560736     Action
# 115  117          X-Men: First Class (2011)     7.8      556713     Action
# 116  118                    Zootopia (2016)     8.1      309474  Animation
#
# ...

# %%
type(df_excel)
# Out:
# pandas.core.frame.DataFrame

# %%
xls_file = pd.ExcelFile('IMDB.xlsx')

# %%
xls_file

# %%
type(xls_file)
# Out:
# pandas.io.excel._base.ExcelFile

# %%
xls_file.sheet_names
# Out:
# ['movies', 'by genre']

# %%
df_excel = pd.read_excel('IMDB.xlsx', sheet_name=0, index_col='Title')

# %%
df_excel
# Out:
#                                      X  Rating  TotalVotes     Genre1  \
# Title
# 12 Years a Slave (2013)              1     8.1      496092  Biography
# 127 Hours (2010)                     2     7.6      297075  Adventure
# 50/50 (2011)                         3     7.7      283935     Comedy
# About Time (2013)                    4     7.8      225412     Comedy
# Amour (2012)                         5     7.9       76121      Drama
# ...                                ...     ...         ...        ...
# Whiplash (2014)                    114     8.5      492285      Drama
# Wreck-It Ralph (2012)              115     7.7      295125  Animation
# X-Men: Days of Future Past (2014)  116     8.0      560736     Action
# X-Men: First Class (2011)          117     7.8      556713     Action
# Zootopia (2016)                    118     8.1      309474  Animation
#
#                                       Genre2   Genre3  MetaCritic  \
# Title
# ...

# %% [markdown]
# # IMDB Html

# %%
movies=pd.read_html("IMDB.html")

# %%
movies[0]
# Out:
#       0                                  1       2           3       4   \
# 0      X                              Title  Rating  TotalVotes  Genre1
# 1      1             12 Years a Slave(2013)     8.1         496     092
# 2      2                   127 Hours (2010)     7.6         297     075
# 3      3                       50/50 (2011)     7.7         283     935
# 4      4                  About Time (2013)     7.8         225     412
# ..   ...                                ...     ...         ...     ...
# 113  114                    Whiplash (2014)     8.5         492     285
# 114  115              Wreck-It Ralph (2012)     7.7         295     125
# 115  116  X-Men: Days of Future Past (2014)       8         560     736
# 116  117          X-Men: First Class (2011)     7.8         556     713
# 117  118                    Zootopia (2016)     8.1         309     474
#
#             5          6           7       8        9   ...        48  \
# ...

# %%
type(movies)
# Out:
# list

# %% [markdown]
# # JSON File

# %%
movies_data=pd.read_json("IMDB.json")

# %%
movies_data
# Out:
#        X                              Title  Rating  TotalVotes     Genre1  \
# 0      1            12 Years a Slave�(2013)     8.1      496092  Biography
# 1      2                   127 Hours�(2010)     7.6      297075  Adventure
# 2      3                       50/50�(2011)     7.7      283935     Comedy
# 3      4                  About Time�(2013)     7.8      225412     Comedy
# 4      5                       Amour�(2012)     7.9       76121      Drama
# ..   ...                                ...     ...         ...        ...
# 112  114                    Whiplash�(2014)     8.5      492285      Drama
# 113  115              Wreck-It Ralph�(2012)     7.7      295125  Animation
# 114  116  X-Men: Days of Future Past�(2014)     8.0      560736     Action
# 115  117          X-Men: First Class�(2011)     7.8      556713     Action
# 116  118                    Zootopia�(2016)     8.1      309474  Animation
#
# ...

# %%
type(movies_data)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # Pickle File

# %%
movies_p=pd.read_pickle("IMDB.p")

# %%
movies_p
# Out:
#        X                               Title  Rating  TotalVotes     Genre1  \
# 0      1            12 Years a SlaveÂ (2013)     8.1      496092  Biography
# 1      2                   127 HoursÂ (2010)     7.6      297075  Adventure
# 2      3                       50/50Â (2011)     7.7      283935     Comedy
# 3      4                  About TimeÂ (2013)     7.8      225412     Comedy
# 4      5                       AmourÂ (2012)     7.9       76121      Drama
# ..   ...                                 ...     ...         ...        ...
# 112  114                    WhiplashÂ (2014)     8.5      492285      Drama
# 113  115              Wreck-It RalphÂ (2012)     7.7      295125  Animation
# 114  116  X-Men: Days of Future PastÂ (2014)     8.0      560736     Action
# 115  117          X-Men: First ClassÂ (2011)     7.8      556713     Action
# 116  118                    ZootopiaÂ (2016)     8.1      309474  Animation
#
# ...

# %% [markdown]
# # SQLite File IMDB

# %%
import sqlite3

# %%
conn = sqlite3.connect("IMDB.sqlite")

# %%
conn

# %%
df = pd.read_sql_query("select * from IMDB",conn)

# %%
df
# Out:
#        X                              Title  Rating  TotalVotes     Genre1  \
# 0      1            12 Years a Slave (2013)     8.1      496092  Biography
# 1      2                   127 Hours (2010)     7.6      297075  Adventure
# 2      3                       50/50 (2011)     7.7      283935     Comedy
# 3      4                  About Time (2013)     7.8      225412     Comedy
# 4      5                       Amour (2012)     7.9       76121      Drama
# ..   ...                                ...     ...         ...        ...
# 112  114                    Whiplash (2014)     8.5      492285      Drama
# 113  115              Wreck-It Ralph (2012)     7.7      295125  Animation
# 114  116  X-Men: Days of Future Past (2014)     8.0      560736     Action
# 115  117          X-Men: First Class (2011)     7.8      556713     Action
# 116  118                    Zootopia (2016)     8.1      309474  Animation
#
# ...
